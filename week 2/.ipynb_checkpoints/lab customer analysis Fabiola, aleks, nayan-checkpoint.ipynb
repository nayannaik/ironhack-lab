# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 50

# %%
new_file3 = pd.read_csv('file3.csv')
new_file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
new_file3.rename(columns={'State':'ST', 'Gender' : 'GENDER'}, inplace=True )
new_file3.to_csv('file 3 clean.csv')

# %%
def load_original_data():
    file1 = pd.read_csv('file1.csv')
    file2 = pd.read_csv('file2.csv')
    file3 = pd.read_csv('file 3 clean.csv')
    return pd.concat([file1,file2,file3], axis=0)

# %%
ica_df=load_original_data()
ica_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def lower_case_column_names(ica_df):
    ica_df.columns=[i.lower() for i in ica_df.columns]
    return ica_df
lower_case_column_names(ica_df)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def drop_columns(ica_df) :
    ica_df.drop(columns =['customer'], inplace = True)
    return ica_df
drop_columns(ica_df)
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
ica_df.reset_index(drop=True, inplace=True)

# %%
ica_df['number of open complaints'].apply(type)
# Out:
# 0        <class 'str'>
# 1        <class 'str'>
# 2        <class 'str'>
# 3        <class 'str'>
# 4        <class 'str'>
#              ...
# 12069    <class 'int'>
# 12070    <class 'int'>
# 12071    <class 'int'>
# 12072    <class 'int'>
# 12073    <class 'int'>
# Name: number of open complaints, Length: 12074, dtype: object

# %%
def clean_numberofcomps(x):
    if isinstance(x, str):
        return x[2]
    else:
        return x

# %%
ica_df["number of open complaints"] = ica_df["number of open complaints"].apply(clean_numberofcomps)

# %%
ica_df
# Out:
#                st gender             education customer lifetime value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 12069  California      M              Bachelor             23405.98798
# 12070  California      F               College             3096.511217
# 12071  California      M              Bachelor             8163.890428
# 12072  California      M               College             7524.442436
# 12073  California      M               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
ica_df.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'Male'
    elif x in ['F', 'Femal','female']:
        return 'Female'
    else:
        return 'nan'

# %%
ica_df['gender'] = ica_df['gender'].apply(clean_gender)
ica_df
# Out:
#                st  gender             education customer lifetime value  \
# 0      Washington     nan                Master                     NaN
# 1         Arizona  Female              Bachelor              697953.59%
# 2          Nevada  Female              Bachelor             1288743.17%
# 3      California    Male              Bachelor              764586.18%
# 4      Washington    Male  High School or Below              536307.65%
# ...           ...     ...                   ...                     ...
# 12069  California    Male              Bachelor             23405.98798
# 12070  California  Female               College             3096.511217
# 12071  California    Male              Bachelor             8163.890428
# 12072  California    Male               College             7524.442436
# 12073  California    Male               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
ica_df.st.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
ica_df['st'] = ica_df['st'].replace({'WA':'Washington', 'AZ':'Arizona','Cali': 'California'})

# %%
ica_df['customer lifetime value'].apply(type)
# Out:
# 0        <class 'float'>
# 1          <class 'str'>
# 2          <class 'str'>
# 3          <class 'str'>
# 4          <class 'str'>
#               ...
# 12069    <class 'float'>
# 12070    <class 'float'>
# 12071    <class 'float'>
# 12072    <class 'float'>
# 12073    <class 'float'>
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
def clean_customerlifetitmvalue(x):
    if isinstance(x, str):
        return x.removesuffix('%')
    else:
        return x

# %%
ica_df['customer lifetime value'] = ica_df['customer lifetime value'].apply(clean_customerlifetitmvalue)

# %%
ica_df['customer lifetime value'] =  pd.to_numeric(ica_df['customer lifetime value'], errors='coerce')
#ica_df['income'] =  pd.to_numeric(ica_df['income'], errors='coerce')

# %%
ica_df.drop_duplicates()
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master                      NaN
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
mean_customer_lifetime_value = np.mean(ica_df['customer lifetime value'])
ica_df['customer lifetime value'] == ica_df['customer lifetime value'].fillna(mean_customer_lifetime_value, inplace = True)
ica_df
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master             1.821964e+05
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
mean_monthly_premium_auto = np.mean(ica_df['monthly premium auto'])
ica_df['monthly premium auto'] == ica_df['monthly premium auto'].fillna('mean_monthly_premium_auto')
ica_df
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master             1.821964e+05
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
mean_income = np.mean(ica_df['income'])
ica_df['income'] == ica_df['income'].fillna(mean_income, inplace = True)
ica_df
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master             1.821964e+05
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
ica_df['number of open complaints'] =  pd.to_numeric(ica_df['number of open complaints'], errors='coerce')

# %%
mean_number_of_open_complaints= np.mean(ica_df['number of open complaints'])
ica_df['number of open complaints'] == ica_df['number of open complaints'].fillna(mean_number_of_open_complaints, inplace = True)
ica_df
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master             1.821964e+05
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
mean_total_claim_amount = np.mean(ica_df['total claim amount'])
ica_df['total claim amount'] == ica_df['total claim amount'].fillna(mean_total_claim_amount, inplace = True)
ica_df
# Out:
#                st  gender             education  customer lifetime value  \
# 0      Washington     nan                Master             1.821964e+05
# 1         Arizona  Female              Bachelor             6.979536e+05
# 2          Nevada  Female              Bachelor             1.288743e+06
# 3      California    Male              Bachelor             7.645862e+05
# 4      Washington    Male  High School or Below             5.363077e+05
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor             2.340599e+04
# 12070  California  Female               College             3.096511e+03
# 12071  California    Male              Bachelor             8.163890e+03
# 12072  California    Male               College             7.524442e+03
# 12073  California    Male               College             2.611837e+03
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
ica_df['st'] = ica_df['st'].replace({'California':'West Region', 'Oregon':'North West','Washington': 'East','Arizona':'Central', 'Nevada':'Central' })

# %%
ica_df
# Out:
#                 st  gender             education  customer lifetime value  \
# 0             East     nan                Master                      NaN
# 1          Central  Female              Bachelor             6.979536e+05
# 2          Central  Female              Bachelor             1.288743e+06
# 3      West Region    Male              Bachelor             7.645862e+05
# 4             East    Male  High School or Below             5.363077e+05
# ...            ...     ...                   ...                      ...
# 12069  West Region    Male              Bachelor             2.340599e+04
# 12070  West Region  Female               College             3.096511e+03
# 12071  West Region    Male              Bachelor             8.163890e+03
# 12072  West Region    Male               College             7.524442e+03
# 12073  West Region    Male               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
ica_df._get_numeric_data()
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 0                 1.821964e+05      0.0                1000.0
# 1                 6.979536e+05      0.0                  94.0
# 2                 1.288743e+06  48767.0                 108.0
# 3                 7.645862e+05      0.0                 106.0
# 4                 5.363077e+05  36357.0                  68.0
# ...                        ...      ...                   ...
# 12069             2.340599e+04  71941.0                  73.0
# 12070             3.096511e+03  21604.0                  79.0
# 12071             8.163890e+03      0.0                  85.0
# 12072             7.524442e+03  21941.0                  96.0
# 12073             2.611837e+03      0.0                  77.0
#
#        number of open complaints  total claim amount  unnamed: 0
# 0                            0.0            2.704934         NaN
# 1                            0.0         1131.464935         NaN
# ...

# %%
ica_df.select_dtypes('object')
# Out:
#                st  gender             education     policy type  vehicle class
# 0      Washington     nan                Master   Personal Auto  Four-Door Car
# 1         Arizona  Female              Bachelor   Personal Auto  Four-Door Car
# 2          Nevada  Female              Bachelor   Personal Auto   Two-Door Car
# 3      California    Male              Bachelor  Corporate Auto            SUV
# 4      Washington    Male  High School or Below   Personal Auto  Four-Door Car
# ...           ...     ...                   ...             ...            ...
# 12069  California    Male              Bachelor   Personal Auto  Four-Door Car
# 12070  California  Female               College  Corporate Auto  Four-Door Car
# 12071  California    Male              Bachelor  Corporate Auto  Four-Door Car
# 12072  California    Male               College   Personal Auto  Four-Door Car
# 12073  California    Male               College  Corporate Auto   Two-Door Car
#
# ...
