# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
import difflib
import random
from IPython.display import IFrame

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= "aa98c6c0093641feb21c982d07440d4e",
                                                           client_secret= "003fa843fbd54442820ae2ed35856e9e"))

# %%
def load_original_data():
    file1 = pd.read_csv('playlisy_3672.csv',index_col = 0)
    file2 = pd.read_csv('playlisy_1612.csv',index_col = 0)
    file3 = pd.read_csv('playlisy_148.csv',index_col = 0)
    file4 = pd.read_csv('playlisy_602.csv',index_col = 0)
    
    
    return pd.concat([file1,file2,file3, file4], axis=0).reset_index(drop=True)

# %%
final_playlist = load_original_data()
final_playlist
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1            0.502   0.912    1    -4.556     1       0.0564      0.000025
# 2            0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3            0.396   0.473   10    -7.670     0       0.0345      0.326000
# 4            0.723   0.863    2    -7.890     1       0.0338      0.038300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6029         0.718   0.357    2    -8.843     1       0.0437      0.407000
# 6030         0.626   0.584    0    -6.913     1       0.1020      0.782000
# 6031         0.708   0.485    2    -5.552     1       0.0699      0.210000
# 6032         0.693   0.643    4    -5.867     0       0.0828      0.138000
# 6033         0.559   0.559   11    -6.425     1       0.0358      0.014500
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1890    0.557   95.263  audio_features
# 1             0.000173    0.1060    0.720  116.761  audio_features
# 2             0.000106    0.9220    0.175  163.219  audio_features
# 3             0.000124    0.1090    0.385  133.449  audio_features
# 4             0.031700    0.1280    0.931  136.302  audio_features
# ...                ...       ...      ...      ...             ...
# 6029          0.000000    0.0897    0.347  146.006  audio_features
# 6030          0.000000    0.2080    0.408  102.045  audio_features
# 6031          0.000000    0.1040    0.281  139.990  audio_features
# 6032          0.000000    0.1080    0.477   95.055  audio_features
# 6033          0.000000    0.1380    0.338   72.498  audio_features
#
#                           id                                   uri  \
# 0     3AhXZa8sUQht0UEdBJgpGc  spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1     4CeeEOM32jQcH3eN9Q2dGj  spotify:track:4CeeEOM32jQcH3eN9Q2dGj
# 2     0hKRSZhUGEhKU6aNSPBACZ  spotify:track:0hKRSZhUGEhKU6aNSPBACZ
# 3     5t9KYe0Fhd5cW6UYT4qP8f  spotify:track:5t9KYe0Fhd5cW6UYT4qP8f
# 4     2PzU4IB8Dr6mxV3lHuaG34  spotify:track:2PzU4IB8Dr6mxV3lHuaG34
# ...                      ...                                   ...
# 6029  4pV3f1Nn5XtyA9x60rFan7  spotify:track:4pV3f1Nn5XtyA9x60rFan7
# 6030  28WoBIA4EDVvxiraTv2KZ2  spotify:track:28WoBIA4EDVvxiraTv2KZ2
# 6031  3K8tRD2Prik7FXbD8lZ6DC  spotify:track:3K8tRD2Prik7FXbD8lZ6DC
# 6032  2UN0lp72LAusrXi8LLVomt  spotify:track:2UN0lp72LAusrXi8LLVomt
# 6033  2m6Ko3CY1qXNNja8AlugNc  spotify:track:2m6Ko3CY1qXNNja8AlugNc
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 1     https://api.spotify.com/v1/tracks/4CeeEOM32jQc...
# 2     https://api.spotify.com/v1/tracks/0hKRSZhUGEhK...
# 3     https://api.spotify.com/v1/tracks/5t9KYe0Fhd5c...
# 4     https://api.spotify.com/v1/tracks/2PzU4IB8Dr6m...
# ...                                                 ...
# 6029  https://api.spotify.com/v1/tracks/4pV3f1Nn5Xty...
# 6030  https://api.spotify.com/v1/tracks/28WoBIA4EDVv...
# 6031  https://api.spotify.com/v1/tracks/3K8tRD2Prik7...
# 6032  https://api.spotify.com/v1/tracks/2UN0lp72LAus...
# 6033  https://api.spotify.com/v1/tracks/2m6Ko3CY1qXN...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3AhX...       369600
# 1     https://api.spotify.com/v1/audio-analysis/4Cee...       301920
# 2     https://api.spotify.com/v1/audio-analysis/0hKR...       337413
# 3     https://api.spotify.com/v1/audio-analysis/5t9K...       219027
# 4     https://api.spotify.com/v1/audio-analysis/2PzU...       222813
# ...                                                 ...          ...
# 6029  https://api.spotify.com/v1/audio-analysis/4pV3...       230548
# 6030  https://api.spotify.com/v1/audio-analysis/28Wo...       183360
# 6031  https://api.spotify.com/v1/audio-analysis/3K8t...       151041
# 6032  https://api.spotify.com/v1/audio-analysis/2UN0...       163450
# 6033  https://api.spotify.com/v1/audio-analysis/2m6K...       220780
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 6029               4
# 6030               4
# 6031               4
# 6032               4
# 6033               4
#
# [6034 rows x 18 columns]

# %%
final_playlist_w_id = final_playlist.drop(final_playlist.columns[[11, 13, 14, 15]], axis=1) 
final_playlist_w_id
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1            0.502   0.912    1    -4.556     1       0.0564      0.000025
# 2            0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3            0.396   0.473   10    -7.670     0       0.0345      0.326000
# 4            0.723   0.863    2    -7.890     1       0.0338      0.038300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6029         0.718   0.357    2    -8.843     1       0.0437      0.407000
# 6030         0.626   0.584    0    -6.913     1       0.1020      0.782000
# 6031         0.708   0.485    2    -5.552     1       0.0699      0.210000
# 6032         0.693   0.643    4    -5.867     0       0.0828      0.138000
# 6033         0.559   0.559   11    -6.425     1       0.0358      0.014500
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1890    0.557   95.263  3AhXZa8sUQht0UEdBJgpGc
# 1             0.000173    0.1060    0.720  116.761  4CeeEOM32jQcH3eN9Q2dGj
# 2             0.000106    0.9220    0.175  163.219  0hKRSZhUGEhKU6aNSPBACZ
# 3             0.000124    0.1090    0.385  133.449  5t9KYe0Fhd5cW6UYT4qP8f
# 4             0.031700    0.1280    0.931  136.302  2PzU4IB8Dr6mxV3lHuaG34
# ...                ...       ...      ...      ...                     ...
# 6029          0.000000    0.0897    0.347  146.006  4pV3f1Nn5XtyA9x60rFan7
# 6030          0.000000    0.2080    0.408  102.045  28WoBIA4EDVvxiraTv2KZ2
# 6031          0.000000    0.1040    0.281  139.990  3K8tRD2Prik7FXbD8lZ6DC
# 6032          0.000000    0.1080    0.477   95.055  2UN0lp72LAusrXi8LLVomt
# 6033          0.000000    0.1380    0.338   72.498  2m6Ko3CY1qXNNja8AlugNc
#
#       duration_ms  time_signature
# 0          369600               4
# 1          301920               4
# 2          337413               4
# 3          219027               4
# 4          222813               4
# ...           ...             ...
# 6029       230548               4
# 6030       183360               4
# 6031       151041               4
# 6032       163450               4
# 6033       220780               4
#
# [6034 rows x 14 columns]

# %% [markdown]
# ### Dropping few columns

# %%
final_playlist = final_playlist.drop(final_playlist.columns[[11, 12, 13, 14, 15]], axis=1) 
final_playlist
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1            0.502   0.912    1    -4.556     1       0.0564      0.000025
# 2            0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3            0.396   0.473   10    -7.670     0       0.0345      0.326000
# 4            0.723   0.863    2    -7.890     1       0.0338      0.038300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6029         0.718   0.357    2    -8.843     1       0.0437      0.407000
# 6030         0.626   0.584    0    -6.913     1       0.1020      0.782000
# 6031         0.708   0.485    2    -5.552     1       0.0699      0.210000
# 6032         0.693   0.643    4    -5.867     0       0.0828      0.138000
# 6033         0.559   0.559   11    -6.425     1       0.0358      0.014500
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1890    0.557   95.263       369600
# 1             0.000173    0.1060    0.720  116.761       301920
# 2             0.000106    0.9220    0.175  163.219       337413
# 3             0.000124    0.1090    0.385  133.449       219027
# 4             0.031700    0.1280    0.931  136.302       222813
# ...                ...       ...      ...      ...          ...
# 6029          0.000000    0.0897    0.347  146.006       230548
# 6030          0.000000    0.2080    0.408  102.045       183360
# 6031          0.000000    0.1040    0.281  139.990       151041
# 6032          0.000000    0.1080    0.477   95.055       163450
# 6033          0.000000    0.1380    0.338   72.498       220780
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 6029               4
# 6030               4
# 6031               4
# 6032               4
# 6033               4
#
# [6034 rows x 13 columns]

# %% [markdown]
# ### Bill Board dataframe (Web Scraping)

# %%
Bill_borad_top_100 = pd.read_csv('Bill board top 100 songs.csv',index_col = 0)

# %%
Bill_borad_top_100
# Out:
#        song_name               song_artist  \
# 0      as it was              harry styles
# 1    first class               jack harlow
# 2     heat waves             glass animals
# 3     big energy                     latto
# 4          enemy     imagine dragons x jid
# ..           ...                       ...
# 95       p power     gunna featuring drake
# 96  money so big                      yeat
# 97  blick blick!   coi leray & nicki minaj
# 98  fall in love          bailey zimmerman
# 99  x ultima vez  daddy yankee & bad bunny
#
#                                         song
# 0                  As It Was by Harry Styles
# 1                 First Class by Jack Harlow
# 2                Heat Waves by Glass Animals
# 3                        Big Energy by Latto
# 4             Enemy by Imagine Dragons X Jid
# ..                                       ...
# 95          P Power by Gunna Featuring Drake
# 96                      Money So Big by Yeat
# 97   Blick Blick! by Coi Leray & Nicki Minaj
# 98          Fall In Love by Bailey Zimmerman
# 99  X Ultima Vez by Daddy Yankee & Bad Bunny
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Normalising DataFrame

# %%
scaler = StandardScaler()
scaler.fit(final_playlist)
final_playlist_scaled = scaler.transform(final_playlist)
final_playlist_scaled_df = pd.DataFrame(final_playlist_scaled, columns = final_playlist.columns)
display(final_playlist.head())
print()
display(final_playlist_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 2         0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3         0.396   0.473   10    -7.670     0       0.0345      0.326000
# 4         0.723   0.863    2    -7.890     1       0.0338      0.038300
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000000     0.189    0.557   95.263       369600               4
# 1          0.000173     0.106    0.720  116.761       301920               4
# 2          0.000106     0.922    0.175  163.219       337413               4
# 3          0.000124     0.109    0.385  133.449       219027               4
# 4          0.031700     0.128    0.931  136.302       222813               4
#    danceability    energy       key  loudness      mode  speechiness  \
# 0     -0.598187  0.414021 -1.481714  0.339724  0.687332    -0.545975
# 1     -0.478795  1.251650 -1.202021  0.856794  0.687332    -0.205648
# 2     -1.302603 -0.743748 -0.362942 -1.318842 -1.454901    -0.050190
# 3     -1.111575 -0.673580  1.315215  0.151513 -1.454901    -0.512363
# 4      0.840491  1.036761 -0.922328  0.101686  0.687332    -0.522166
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0      1.438948         -0.378862  0.047590  0.053768 -0.907554     1.251262
# 1     -0.920324         -0.378087 -0.504151  0.707631 -0.122185     0.613233
# 2      0.015589         -0.378387  4.920195 -1.478599  1.575028     0.947831
# 3      0.131782         -0.378307 -0.484209 -0.636199  0.487464    -0.168211
# 4     -0.796790         -0.236890 -0.357906  1.554043  0.591691    -0.132520
#
#    time_signature
# 0        0.197588
# 1        0.197588
# 2        0.197588
# 3        0.197588
# 4        0.197588

# %% [markdown]
# ### Clustering with K-Means

# %%
kmeans = KMeans(n_clusters=7, random_state=1234)
kmeans.fit(final_playlist_scaled_df)
# Out:
# KMeans(n_clusters=7, random_state=1234)

# %%
# assign a cluster to each example
labels = kmeans.predict(final_playlist_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(final_playlist.to_numpy()[row_ix, 1], final_playlist.to_numpy()[row_ix, 6])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(final_playlist_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     992
# 1     387
# 2     307
# 3    1845
# 4    1004
# 5     207
# 6    1292
# dtype: int64

# %% [markdown]
# #### Adding cluster column

# %%
final_playlist["cluster"] = clusters
final_playlist
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1            0.502   0.912    1    -4.556     1       0.0564      0.000025
# 2            0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3            0.396   0.473   10    -7.670     0       0.0345      0.326000
# 4            0.723   0.863    2    -7.890     1       0.0338      0.038300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6029         0.718   0.357    2    -8.843     1       0.0437      0.407000
# 6030         0.626   0.584    0    -6.913     1       0.1020      0.782000
# 6031         0.708   0.485    2    -5.552     1       0.0699      0.210000
# 6032         0.693   0.643    4    -5.867     0       0.0828      0.138000
# 6033         0.559   0.559   11    -6.425     1       0.0358      0.014500
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1890    0.557   95.263       369600
# 1             0.000173    0.1060    0.720  116.761       301920
# 2             0.000106    0.9220    0.175  163.219       337413
# 3             0.000124    0.1090    0.385  133.449       219027
# 4             0.031700    0.1280    0.931  136.302       222813
# ...                ...       ...      ...      ...          ...
# 6029          0.000000    0.0897    0.347  146.006       230548
# 6030          0.000000    0.2080    0.408  102.045       183360
# 6031          0.000000    0.1040    0.281  139.990       151041
# 6032          0.000000    0.1080    0.477   95.055       163450
# 6033          0.000000    0.1380    0.338   72.498       220780
#
#       time_signature  cluster
# 0                  4        4
# 1                  4        3
# 2                  4        0
# 3                  4        6
# 4                  4        3
# ...              ...      ...
# 6029               4        4
# 6030               4        4
# 6031               4        3
# 6032               4        6
# 6033               4        3
#
# [6034 rows x 14 columns]

# %%
final_playlist_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0        -0.598187  0.414021 -1.481714  0.339724  0.687332    -0.545975
# 1        -0.478795  1.251650 -1.202021  0.856794  0.687332    -0.205648
# 2        -1.302603 -0.743748 -0.362942 -1.318842 -1.454901    -0.050190
# 3        -1.111575 -0.673580  1.315215  0.151513 -1.454901    -0.512363
# 4         0.840491  1.036761 -0.922328  0.101686  0.687332    -0.522166
# ...            ...       ...       ...       ...       ...          ...
# 6029      0.810643 -1.182297 -0.922328 -0.114157  0.687332    -0.383515
# 6030      0.261438 -0.186791 -1.481714  0.322964  0.687332     0.432991
# 6031      0.750947 -0.620954 -0.922328  0.631213  0.687332    -0.016577
# 6032      0.661403  0.071953 -0.362942  0.559869 -1.454901     0.164090
# 6033     -0.138527 -0.296428  1.594907  0.433490  0.687332    -0.494156
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0         1.438948         -0.378862  0.047590  0.053768 -0.907554
# 1        -0.920324         -0.378087 -0.504151  0.707631 -0.122185
# 2         0.015589         -0.378387  4.920195 -1.478599  1.575028
# 3         0.131782         -0.378307 -0.484209 -0.636199  0.487464
# 4        -0.796790         -0.236890 -0.357906  1.554043  0.591691
# ...            ...               ...       ...       ...       ...
# 6029      0.393215         -0.378862 -0.612505 -0.788633  0.946199
# 6030      1.603554         -0.378862  0.173892 -0.543936 -0.659792
# 6031     -0.242616         -0.378862 -0.517446 -1.053387  0.726421
# 6032     -0.475001         -0.378862 -0.490856 -0.267147 -0.915152
# 6033     -0.873606         -0.378862 -0.291432 -0.824736 -1.739209
#
#       duration_ms  time_signature
# 0        1.251262        0.197588
# 1        0.613233        0.197588
# 2        0.947831        0.197588
# 3       -0.168211        0.197588
# 4       -0.132520        0.197588
# ...           ...             ...
# 6029    -0.059601        0.197588
# 6030    -0.504449        0.197588
# 6031    -0.809125        0.197588
# 6032    -0.692143        0.197588
# 6033    -0.151685        0.197588
#
# [6034 rows x 13 columns]

# %%
playlist = pd.concat([final_playlist_scaled_df, final_playlist.cluster, final_playlist_w_id.id ], axis =1)
playlist
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0        -0.598187  0.414021 -1.481714  0.339724  0.687332    -0.545975
# 1        -0.478795  1.251650 -1.202021  0.856794  0.687332    -0.205648
# 2        -1.302603 -0.743748 -0.362942 -1.318842 -1.454901    -0.050190
# 3        -1.111575 -0.673580  1.315215  0.151513 -1.454901    -0.512363
# 4         0.840491  1.036761 -0.922328  0.101686  0.687332    -0.522166
# ...            ...       ...       ...       ...       ...          ...
# 6029      0.810643 -1.182297 -0.922328 -0.114157  0.687332    -0.383515
# 6030      0.261438 -0.186791 -1.481714  0.322964  0.687332     0.432991
# 6031      0.750947 -0.620954 -0.922328  0.631213  0.687332    -0.016577
# 6032      0.661403  0.071953 -0.362942  0.559869 -1.454901     0.164090
# 6033     -0.138527 -0.296428  1.594907  0.433490  0.687332    -0.494156
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0         1.438948         -0.378862  0.047590  0.053768 -0.907554
# 1        -0.920324         -0.378087 -0.504151  0.707631 -0.122185
# 2         0.015589         -0.378387  4.920195 -1.478599  1.575028
# 3         0.131782         -0.378307 -0.484209 -0.636199  0.487464
# 4        -0.796790         -0.236890 -0.357906  1.554043  0.591691
# ...            ...               ...       ...       ...       ...
# 6029      0.393215         -0.378862 -0.612505 -0.788633  0.946199
# 6030      1.603554         -0.378862  0.173892 -0.543936 -0.659792
# 6031     -0.242616         -0.378862 -0.517446 -1.053387  0.726421
# 6032     -0.475001         -0.378862 -0.490856 -0.267147 -0.915152
# 6033     -0.873606         -0.378862 -0.291432 -0.824736 -1.739209
#
#       duration_ms  time_signature  cluster                      id
# 0        1.251262        0.197588        4  3AhXZa8sUQht0UEdBJgpGc
# 1        0.613233        0.197588        3  4CeeEOM32jQcH3eN9Q2dGj
# 2        0.947831        0.197588        0  0hKRSZhUGEhKU6aNSPBACZ
# 3       -0.168211        0.197588        6  5t9KYe0Fhd5cW6UYT4qP8f
# 4       -0.132520        0.197588        3  2PzU4IB8Dr6mxV3lHuaG34
# ...           ...             ...      ...                     ...
# 6029    -0.059601        0.197588        4  4pV3f1Nn5XtyA9x60rFan7
# 6030    -0.504449        0.197588        4  28WoBIA4EDVvxiraTv2KZ2
# 6031    -0.809125        0.197588        3  3K8tRD2Prik7FXbD8lZ6DC
# 6032    -0.692143        0.197588        6  2UN0lp72LAusrXi8LLVomt
# 6033    -0.151685        0.197588        3  2m6Ko3CY1qXNNja8AlugNc
#
# [6034 rows x 15 columns]

# %%
final_playlist['cluster'].value_counts()
# Out:
# 3    1845
# 6    1292
# 4    1004
# 0     992
# 1     387
# 2     307
# 5     207
# Name: cluster, dtype: int64

# %%
kmeans2 = KMeans(n_clusters=50,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(final_playlist_scaled_df)
print(kmeans2.inertia_)
# Out:
# 26053.705428938403

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(final_playlist_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
def Recommendation():
    Song = input("Enter your song: ")
    if Bill_borad_top_100.song_name.str.contains(Song, na = False, case=False).any()==True:
        print("Recommended Hot Song : " + random.choice(Bill_borad_top_100.song))
    else:
        if difflib.get_close_matches(Song, Bill_borad_top_100.song_name, n = 1)!= []:
            print("Did you mean: " + difflib.get_close_matches(Song, Bill_borad_top_100.song_name, n = 1)[0])
            yes_no = input("Yes/No") 
            if yes_no == "Yes":
                print("Another Recommended Hot Song : " + random.choice(Bill_borad_top_100.song))
            elif yes_no == "No":
                a = sp.search(Song,limit=1,market="GB")
                b = sp.audio_features(a['tracks']['items'][0]['uri'])
                c = pd.json_normalize(b)
                c = c.drop(c.columns[[11, 12, 13, 14, 15]], axis=1) 
                c_scaled = scaler.transform(c)
                c_scaled_df = pd.DataFrame(c_scaled, columns = c.columns)
                d = kmeans.predict(c_scaled_df)
                e = d[0].item()
                id_column = list(playlist[playlist['cluster'] == e ]['id'])
                track_id = random.sample(id_column, 1)
                track_id = track_id[0]
                X = IFrame(src="https://open.spotify.com/embed/track/"+track_id,
                width="320", height="80",
                frameborder="0", allowtransparency="true", allow="encrypted-media")
     
        
        else:
                a = sp.search(Song,limit=1,market="GB")
                b = sp.audio_features(a['tracks']['items'][0]['uri'])
                c = pd.json_normalize(b)
                c = c.drop(c.columns[[11, 12, 13, 14, 15]], axis=1) 
                c_scaled = scaler.transform(c)
                c_scaled_df = pd.DataFrame(c_scaled, columns = c.columns)
                d = kmeans.predict(c_scaled_df)
                e = d[0].item()
                id_column = list(playlist[playlist['cluster'] == e ]['id'])
                track_id = random.sample(id_column, 1)
                track_id = track_id[0]
                X = IFrame(src="https://open.spotify.com/embed/track/"+track_id,
                width="320", height="80",
                frameborder="0", allowtransparency="true", allow="encrypted-media")
                return(X)

# %%
Recommendation()
# Out:
# Enter your song: never enough
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [237], in <cell line: 1>()
# ----> 1 Recommendation()
#
# Input In [236], in Recommendation()
#      36 e = d[0].item()
#      37 id_column = list(playlist[playlist['cluster'] == e ]['id'])
# ---> 38 track_id = random.sample(id_column, 1)
#      39 track_id = track_id[0]
#      40 X = IFrame(src="https://open.spotify.com/embed/track/"+track_id,
#      41 width="320", height="80",
#      42 frameborder="0", allowtransparency="true", allow="encrypted-media")
#
# File ~/opt/anaconda3/envs/DA_env/lib/python3.9/random.py:449, in Random.sample(self, population, k, counts)
#     447 randbelow = self._randbelow
#     448 if not 0 <= k <= n:
# --> 449     raise ValueError("Sample larger than population or is negative")
#     450 result = [None] * k
#     451 setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
Recommendation()

# %%
playlist.danceability.min()
# Out:
# -3.4755449250266492
