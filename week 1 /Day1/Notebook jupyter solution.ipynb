# %% [markdown]
# # Zee's Holiday preference
# ---
#
# The purpose of the Notebook is to give holiday preferences of my friend

# %%
input("name of my friend: ")
input("")
# Out:
# name of my friend:

# %% [markdown]
# Since Zee want to see northern lights, see can visit
# - <b>Iceland</b>
# - <b>Norway</b>
# - <b>Finland</b>

# %%
input("name of my country: ")
input("")
# Out:
# name of my country: iceland

# %% [markdown]
# <b>Links for must do things</b>
# - __[Best time to see northern lights](https://www.google.com/search?q=when+is+the+best+time+to+see+northern+lights+&sxsrf=APq-WBvJBsT8NEwr9gfbsmuyj8zA6QldsQ%3A1647896246299&ei=tuY4YsHmEb-P9u8PgISIkA4&ved=0ahUKEwjBmYzzi9j2AhW_h_0HHQACAuIQ4dUDCA4&uact=5&oq=when+is+the+best+time+to+see+northern+lights+&gs_lcp=Cgdnd3Mtd2l6EAMyBAgjECcyCggAEIAEEIcCEBQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDoHCAAQRxCwAzoKCAAQRxCwAxDJAzoGCAAQCBAeSgQIQRgASgQIRhgAUKECWOoQYLsTaAFwAXgAgAGXAYgB-QiSAQM0LjaYAQCgAQHIAQjAAQE&sclient=gws-wiz)__
# - __[Ice cave tour](https://www.google.com/search?q=ice+cave+tour&sxsrf=APq-WBtUPcpGNQIal3nCNhSBIQZi-cntuA%3A1647896696830&ei=eOg4YumAMsaFxc8P29-l6Ak&ved=0ahUKEwjpnPbJjdj2AhXGQvEDHdtvCZ0Q4dUDCA4&uact=5&oq=ice+cave+tour&gs_lcp=&sclient=gws-wiz)__

# %% [markdown]
# ![download.jpeg](attachment:download.jpeg)

# %% [markdown]
# ![download%20%281%29.jpeg](attachment:download%20%281%29.jpeg)
